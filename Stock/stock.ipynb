# %%
# Run the following code to install all the required libraries
# %pip install pandas numpy matplotlib seaborn scikit-learn tensorflow boto3 pycaret
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (3.7.5)
# Requirement already satisfied: seaborn in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (1.4.2)
# Requirement already satisfied: tensorflow in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (2.18.0)
# Requirement already satisfied: boto3 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (1.35.68)
# Requirement already satisfied: pycaret in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (3.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: botocore<1.36.0,>=1.35.68 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from boto3) (1.35.68)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from boto3) (0.10.4)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (8.29.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (8.1.5)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (4.67.0)
# Requirement already satisfied: jinja2>=3 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (3.1.4)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (0.12.4)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (2.6.4)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (4.5.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (0.60.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (6.1.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (8.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (3.1.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (0.14.4)
# Requirement already satisfied: sktime==0.26.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from botocore<1.36.0,>=1.35.68->boto3) (2.2.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.21.0)
# Requirement already satisfied: decorator in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: exceptiongroup in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (1.2.2)
# Requirement already satisfied: colorama in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.13)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from numba>=0.55.0->pycaret) (0.43.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from plotly>=5.14.0->pycaret) (9.0.0)
# Requirement already satisfied: dash>=2.9.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.18.2)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.12)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.6)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: retrying in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.21.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (308)
# Requirement already satisfied: rich in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.1)
# Requirement already satisfied: wcwidth in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mikol\onedrive\pulpit\cloud ai\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import os

# %%
# Check if the files exist before loading the datasets
disney_file_path = 'datasets/disney_daily.csv'
warner_file_path = 'datasets/warner_bros_daily.csv'

if not os.path.exists(disney_file_path) or not os.path.exists(warner_file_path):
    raise FileNotFoundError("One or both of the dataset files do not exist. Please check the file paths.")

# Loading the datasets
disney_data = pd.read_csv(disney_file_path)
warner_data = pd.read_csv(warner_file_path)

# Correcting the 'Date' column to handle timezone and format issues
disney_data['Date'] = disney_data['Date'].astype(str).str.replace(r"(\+|-)\d{2}:\d{2}$", "", regex=True)
disney_data['Date'] = pd.to_datetime(disney_data['Date'], errors='coerce', utc=True).dt.tz_localize(None)

warner_data['Date'] = warner_data['Date'].astype(str).str.replace(r"(\+|-)\d{2}:\d{2}$", "", regex=True)
warner_data['Date'] = pd.to_datetime(warner_data['Date'], errors='coerce', utc=True).dt.tz_localize(None)

# Dropping rows where 'Date' could not be converted properly
disney_data.dropna(subset=['Date'], inplace=True)
warner_data.dropna(subset=['Date'], inplace=True)

# Renaming columns to remove spaces and make them lowercase
disney_data.columns = disney_data.columns.str.lower().str.replace(' ', '_')
warner_data.columns = warner_data.columns.str.lower().str.replace(' ', '_')

# Initial Exploration
def initial_exploration(df, company_name):
    print(f"\nInitial Exploration for {company_name}")
    print(df.info())
    print(df.describe())
    print(df.head())

initial_exploration(disney_data, "Disney")
initial_exploration(warner_data, "Warner Bros")

# Cleaning the Data
def clean_data(df):
    # Handling missing values
    df.fillna(method='ffill', inplace=True)
    df.fillna(method='bfill', inplace=True)
    return df

disney_data = clean_data(disney_data)
warner_data = clean_data(warner_data)

# Exploratory Data Analysis (EDA)
def plot_stock_prices(df, company_name):
    plt.figure(figsize=(12, 6))
    sns.lineplot(x=df['date'], y=df['close'], label=f'{company_name} Closing Prices')
    plt.xlabel('Year')
    plt.ylabel('Stock Price')
    plt.title(f'{company_name} Stock Prices Over Time')
    plt.legend()
    plt.show()

plot_stock_prices(disney_data, "Disney")
plot_stock_prices(warner_data, "Warner Bros")

# Comparing both companies
plt.figure(figsize=(12, 6))
sns.lineplot(x=disney_data['date'], y=disney_data['close'], label='Disney Closing Prices')
sns.lineplot(x=warner_data['date'], y=warner_data['close'], label='Warner Bros Closing Prices')
plt.xlabel('Year')
plt.ylabel('Stock Price')
plt.title('Comparison of Disney and Warner Bros Stock Prices')
plt.legend()
plt.show()

# %%
# Feature Engineering and Splitting Data for Predictions
# Filtering data up to 2019 for training
disney_train_data = disney_data[disney_data['date'].dt.year <= 2019]

# Ensure that there is data available for future predictions
disney_future_data = disney_data[(disney_data['date'].dt.year > 2019)]
if disney_future_data.empty:
    raise ValueError("No data available for future predictions for Disney. Please check the dataset or the filtering conditions.")

disney_features = disney_train_data[['open', 'high', 'low', 'volume']]
disney_target = disney_train_data['close']

# Scaling the features
scaler_disney = StandardScaler()
X_train_scaled_disney = scaler_disney.fit_transform(disney_features)

# Model Building and Training
# Neural Network Model Building for Disney
model_disney = Sequential()
model_disney.add(Dense(64, input_dim=X_train_scaled_disney.shape[1], activation='relu'))
model_disney.add(Dense(32, activation='relu'))
model_disney.add(Dense(16, activation='relu'))
model_disney.add(Dense(1))

optimizer_disney = Adam(learning_rate=0.001)
model_disney.compile(optimizer=optimizer_disney, loss='mse', metrics=['mae'])

# Early stopping and model checkpoint callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, min_delta=0.001)
model_checkpoint = ModelCheckpoint(filepath='best_disney_model.keras', monitor='val_loss', save_best_only=True)

# Training the model
history_disney = model_disney.fit(X_train_scaled_disney, disney_target, epochs=50, batch_size=8, verbose=1, validation_split=0.2, callbacks=[early_stopping, model_checkpoint])

# Plotting training history for Disney
plt.figure(figsize=(10, 6))
sns.lineplot(data=history_disney.history, palette='tab10', linewidth=2.5)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss for Disney Model')
plt.legend(['Training Loss', 'Validation Loss'])
plt.show()

# %%
# Feature Engineering and Splitting Data for Predictions
# Filtering data up to 2019 for training
warner_train_data = warner_data[warner_data['date'].dt.year <= 2019]

# Ensure that there is data available for future predictions
warner_future_data = warner_data[(warner_data['date'].dt.year > 2019)]
if warner_future_data.empty:
    raise ValueError("No data available for future predictions for Warner Bros. Please check the dataset or the filtering conditions.")

warner_features = warner_train_data[['open', 'high', 'low', 'volume']]
warner_target = warner_train_data['close']

# Scaling the features
scaler_warner = StandardScaler()
X_train_scaled_warner = scaler_warner.fit_transform(warner_features)

# Neural Network Model Building for Warner Bros
model_warner = Sequential()
model_warner.add(Dense(64, input_dim=X_train_scaled_warner.shape[1], activation='relu'))
model_warner.add(Dense(32, activation='relu'))
model_warner.add(Dense(16, activation='relu'))
model_warner.add(Dense(1))

optimizer_warner = Adam(learning_rate=0.001)
model_warner.compile(optimizer=optimizer_warner, loss='mse', metrics=['mae'])

# Training the model
history_warner = model_warner.fit(X_train_scaled_warner, warner_target, epochs=50, batch_size=8, verbose=1, validation_split=0.2, callbacks=[early_stopping])

# Plotting training history for Warner Bros
plt.figure(figsize=(10, 6))
sns.lineplot(data=history_warner.history, palette='tab10', linewidth=2.5)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss for Warner Bros Model')
plt.legend(['Training Loss', 'Validation Loss'])
plt.show()

# %%
# Preparing data for future predictions (2020-2024) and saving the best models

disney_future_features = disney_future_data[['open', 'high', 'low', 'volume']]
disney_future_features_scaled = scaler_disney.transform(disney_future_features)

# Predicting Future Stock Prices for Disney
y_pred_disney = model_disney.predict(disney_future_features_scaled)

# Saving Disney model
model_disney.save('best_disney_model.keras')

# Plotting Future Predictions for Disney
plt.figure(figsize=(10, 6))
sns.scatterplot(x=disney_future_data['date'], y=disney_future_data['close'], label='Actual Stock Prices', alpha=0.6, s=10)
sns.scatterplot(x=disney_future_data['date'], y=y_pred_disney.flatten(), label='Predicted Stock Prices', alpha=0.6, s=10)
plt.xlabel('Date')
plt.ylabel('Stock Prices')
plt.title('Actual vs Predicted Stock Prices for Disney (2020-2024)')
plt.legend()
plt.show()
# Calculating metrics for Disney
mse_disney = mean_squared_error(disney_future_data['close'], y_pred_disney)
mae_disney = mean_absolute_error(disney_future_data['close'], y_pred_disney)
rmse_disney = np.sqrt(mse_disney)
r2_disney = r2_score(disney_future_data['close'], y_pred_disney)
training_loss_disney = history_disney.history['loss'][-1]
validation_loss_disney = history_disney.history['val_loss'][-1]
print(f"Disney Model - Mean Squared Error: {mse_disney}")
print(f"Disney Model - Mean Absolute Error: {mae_disney}")
print(f"Disney Model - Root Mean Squared Error: {rmse_disney}")
print(f"Disney Model - R2 Score: {r2_disney}")
print(f"Disney Model - Training Loss: {training_loss_disney}")
print(f"Disney Model - Validation Loss: {validation_loss_disney}")

# %%
# Preparing data for future predictions for Warner Bros
warner_future_features = warner_future_data[['open', 'high', 'low', 'volume']]
warner_future_features_scaled = scaler_warner.transform(warner_future_features)

# Predicting Future Stock Prices for Warner Bros
y_pred_warner = model_warner.predict(warner_future_features_scaled)

# Saving Warner Bros model
model_warner.save('best_warner_bros_model.keras')

# Plotting Future Predictions for Warner Bros
plt.figure(figsize=(10, 6))
sns.scatterplot(x=warner_future_data['date'], y=warner_future_data['close'], label='Actual Stock Prices', alpha=0.6, s=10)
sns.scatterplot(x=warner_future_data['date'], y=y_pred_warner.flatten(), label='Predicted Stock Prices', alpha=0.6, s=10)
plt.xlabel('Date')
plt.ylabel('Stock Prices')
plt.title('Actual vs Predicted Stock Prices for Warner Bros (2020-2024)')
plt.legend()
plt.show()

# Calculating metrics for Warner Bros
mse_warner = mean_squared_error(warner_future_data['close'], y_pred_warner)
mae_warner = mean_absolute_error(warner_future_data['close'], y_pred_warner)
rmse_warner = np.sqrt(mse_warner)
r2_warner = r2_score(warner_future_data['close'], y_pred_warner)
training_loss_warner = history_warner.history['loss'][-1]
validation_loss_warner = history_warner.history['val_loss'][-1]
print(f"Warner Bros Model - Mean Squared Error: {mse_warner}")
print(f"Warner Bros Model - Mean Absolute Error: {mae_warner}")
print(f"Warner Bros Model - Root Mean Squared Error: {rmse_warner}")
print(f"Warner Bros Model - R2 Score: {r2_warner}")
print(f"Warner Bros Model - Training Loss: {training_loss_warner}")
print(f"Warner Bros Model - Validation Loss: {validation_loss_warner}")
